# %% [markdown]
# # Scraping Top 100 Chess Players Details using Python
#
# ## In this project we are going scrape Top 100 Chess Players in the world by Rating category.

# %% [markdown]
# ### Web Scraping is the process of extracting and parsing data from websites in an automated fashion using computer program
# 1. Importing requests library
# 2. Downloading web pages using requests library
# 3. Requests library allows you to access the HTTP links
#
# ![](https://i.imgur.com/heKuzSD.png)

# %% [markdown]
# ### Chess Rankings Website
# Chess-ranking.com is a website which provides list of world top 100 chess players by rating category.
# ![](https://i.imgur.com/cdBW0aV.jpeg)

# %% [markdown]
# ##### **Objective**:
# Scraping the `Top 100 Chess Players` in each rating category by parsing the information from this website in the form of Tabular data.

# %% [markdown]
# #####  **List of creative fields on website:**
#
# 1. Rank
# 2. Rank Change
# 3. Name
# 4. Title
# 5. Federation
# 6. Rating
# 7. Rating Change
# 8. Age
# 9. K

# %% [markdown]
# ## **Outline of the project:**
# 1. Understanding the structure of [Chess Rankings Website]("www.chess-rankings.com")
# 2. Installing and Importing required libraries
# 3. Extracting the Player's details of different fields from website using `BeautifulSoup`
# 4. Parsing the Top 100 Chess Players details into 9 fields: Rank, Rank Change,Name, Title, Federation, Rating, Rating Change, Age and K using Helper Functions.
# 5. Storing the extracted data into a dictionary.
# 6. Compiling all the data into a DataFrame using `Pandas` and saving the data  into `CSV` file.

# %%
# Install the library
# !pip install requests --upgrade --quiet

# %%
import requests

# %%
url_1 = "https://chess-rankings.com/?categ=3000&label=1"

# %% [markdown]
# #### To download the web page we are using the requests.get function

# %%
response = requests.get(url_1)

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# #### If the request was successful the value of the response code will be between 200 to 299

# %%
response.status_code
# Out:
# 200

# %%
page_contents = response.text

# %%
len(page_contents)
# Out:
# 63569

# %% [markdown]
# #### The page contains over 63,596 characters! so that we will just view first 1000 characters from the webpage.

# %%
page_contents[:1000]
# Out:
# '\n\n\n\n\n\n<!DOCTYPE html>\n<html   style="min-width:375px;width:100%;overflow-x:hidden">\n<head>\n<meta charset="UTF-8" />\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> \n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="description" content="Chess Live Rankings & Ratings, player games🔥🔥 🤖 Statistics, graphs, customized ranks, players by country, by age,  calculators, world ⌛ Chess Tournaments ~400.000 players database " />\n<meta name="keywords" content="Ajedrez, España, Ajedrez España, Chess, Ranking, Sub 2300, Sub 2000, ajedrez por edades, categorias, top, elo FIDE" />\n\n<!--plugin fb-->\n  <meta property="og:url"           content="https://chess-rankings.com" />\n  <meta property="og:type"          content="website" />\n  <meta property="og:title"         content="Chess-Rankings" />\n  <meta property="og:description"   content="Chess Live Rankings & Ratings, player games🔥🔥 🤖 Stat'

# %% [markdown]
# ### Creating a file and Writing page contents into it

# %%
with open('chess-rankings.html', 'w', encoding="utf-8") as file:
    file.write(page_contents)

# %%
# Install the library
# !pip install beautifulsoup4 --upgrade --quiet

# %% [markdown]
# ## Use Beautiful Soup to parse and extract information
# #### To extract the information from the HTML source code of a page we can use BeautifulSoup library to import that we have to use import BeautifulSoup from the bs4 module.

# %%
from bs4 import BeautifulSoup

# %%
with open('chess-rankings.html', 'r') as f:
    html_source = f.read()

# %%
html_source[:1000]
# Out:
# '\n\n\n\n\n\n<!DOCTYPE html>\n<html   style="min-width:375px;width:100%;overflow-x:hidden">\n<head>\n<meta charset="UTF-8" />\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> \n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="description" content="Chess Live Rankings & Ratings, player games🔥🔥 🤖 Statistics, graphs, customized ranks, players by country, by age,  calculators, world ⌛ Chess Tournaments ~400.000 players database " />\n<meta name="keywords" content="Ajedrez, España, Ajedrez España, Chess, Ranking, Sub 2300, Sub 2000, ajedrez por edades, categorias, top, elo FIDE" />\n\n<!--plugin fb-->\n  <meta property="og:url"           content="https://chess-rankings.com" />\n  <meta property="og:type"          content="website" />\n  <meta property="og:title"         content="Chess-Rankings" />\n  <meta property="og:description"   content="Chess Live Rankings & Ratings, player games🔥🔥 🤖 Stat'

# %% [markdown]
# #### Parsing the HTML webpage with beautifulsoup to read the the content present in that page

# %%
doc = BeautifulSoup(html_source, 'html.parser')

# %%
type(doc)
# Out:
# bs4.BeautifulSoup

# %%
doc.title
# Out:
# <title>Live Chess Ratings &amp; Rankings - Chess-Rankings.com
#   </title>

# %%
doc.title.text
# Out:
# 'Live Chess Ratings & Rankings - Chess-Rankings.com\n  '

# %% [markdown]
# #### Fetching the rows with find_all function in the webpage to get the data present in it.

# %%
rows = doc.tbody.find_all('tr')

# %%
rows[:5]
# Out:
# [<tr id="1"><td>1</td><td>-</td><td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Carlsen, Magnus&amp;id=1503014">    Carlsen, Magnus     </a></td><td class="GM" style="font-weight:bold;">  GM  </td><td><img height="22" src="https://chess-rankings.com/img/banderas/no.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Norway" width="35"/></td><td>  2864  </td><td>  0  </td><td>  32  </td><td>  10  </td></tr>,
#  <tr id="2"><td>2</td><td>-</td><td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Ding, Liren&amp;id=8603677">    Ding, Liren     </a></td><td class="GM" style="font-weight:bold;">  GM  </td><td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td><td>  2808.4  </td><td class="subeElo"> +2.4  </td><td>  30  </td><td>  10  </td></tr>,
#  <tr id="3"><td>3</td><td class="subeElo">↑4</td><td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Nepomniachtchi, Ian&amp;id=4168119">    Nepomniachtchi, Ian     </a></td><td class="GM" style="font-weight:bold;">  GM  </td><td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td><td>  2792.4  </td><td class="subeElo"> +26.4  </td><td>  32  </td><td>  10  </td></tr>,
#  <tr id="4"><td>4</td><td class="bajaElo">↓1</td><td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Firouzja, Alireza&amp;id=12573981">    Firouzja, Alireza     </a></td><td class="GM" style="font-weight:bold;">  GM  </td><td><img height="22" src="https://chess-rankings.com/img/banderas/fr.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="France" width="35"/></td><td>  2778.2  </td><td class="bajaElo">  -14.8  </td><td>  19  </td><td>  10  </td></tr>,
#  <tr id="5"><td>5</td><td class="bajaElo">↓1</td><td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Caruana, Fabiano&amp;id=2020009">    Caruana, Fabiano     </a></td><td class="GM" style="font-weight:bold;">  GM  </td><td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td><td>  2775.4  </td><td class="bajaElo">  -7.6  </td><td>  30  </td><td>  10  </td></tr>]

# %% [markdown]
# #### Creating dictionary for append data inside it

# %%
rank = []
rank_change = []
name = []
title = []
fed = []
rating = []
rating_change = []
age = []
k = []
table_dict = {'Rank': rank,
              'Rank Change': rank_change,
              'Name': name,
              'Title':title,
              'Federation':fed,
              'FIDE Rating': rating,
              'Rating Change':rating_change,
              'Age':age,
              'K':k
              }

# %%
doc.tbody.find_all('td')
# Out:
# [<td>1</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Carlsen, Magnus&amp;id=1503014">    Carlsen, Magnus     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/no.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Norway" width="35"/></td>,
#  <td>  2864  </td>,
#  <td>  0  </td>,
#  <td>  32  </td>,
#  <td>  10  </td>,
#  <td>2</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Ding, Liren&amp;id=8603677">    Ding, Liren     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2808.4  </td>,
#  <td class="subeElo"> +2.4  </td>,
#  <td>  30  </td>,
#  <td>  10  </td>,
#  <td>3</td>,
#  <td class="subeElo">↑4</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Nepomniachtchi, Ian&amp;id=4168119">    Nepomniachtchi, Ian     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2792.4  </td>,
#  <td class="subeElo"> +26.4  </td>,
#  <td>  32  </td>,
#  <td>  10  </td>,
#  <td>4</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Firouzja, Alireza&amp;id=12573981">    Firouzja, Alireza     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fr.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="France" width="35"/></td>,
#  <td>  2778.2  </td>,
#  <td class="bajaElo">  -14.8  </td>,
#  <td>  19  </td>,
#  <td>  10  </td>,
#  <td>5</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Caruana, Fabiano&amp;id=2020009">    Caruana, Fabiano     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2775.4  </td>,
#  <td class="bajaElo">  -7.6  </td>,
#  <td>  30  </td>,
#  <td>  10  </td>,
#  <td>6</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Aronian, Levon&amp;id=13300474">    Aronian, Levon     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2775  </td>,
#  <td>  0  </td>,
#  <td>  40  </td>,
#  <td>  10  </td>,
#  <td>7</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=So, Wesley&amp;id=5202213">    So, Wesley     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2773  </td>,
#  <td>  0  </td>,
#  <td>  29  </td>,
#  <td>  10  </td>,
#  <td>8</td>,
#  <td class="subeElo">↑3</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Nakamura, Hikaru&amp;id=2016192">    Nakamura, Hikaru     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2767.8  </td>,
#  <td class="subeElo"> +7.8  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>9</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Giri, Anish&amp;id=24116068">    Giri, Anish     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/nl.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Netherlands" width="35"/></td>,
#  <td>  2760  </td>,
#  <td>  0  </td>,
#  <td>  28  </td>,
#  <td>  10  </td>,
#  <td>10</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Vachier-Lagrave, Maxime&amp;id=623539">    Vachier-Lagrave, Maxime     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fr.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="France" width="35"/></td>,
#  <td>  2760  </td>,
#  <td>  0  </td>,
#  <td>  32  </td>,
#  <td>  10  </td>,
#  <td>11</td>,
#  <td class="subeElo">↑1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Mamedyarov, Shakhriyar&amp;id=13401319">    Mamedyarov, Shakhriyar     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/az.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Azerbaijan" width="35"/></td>,
#  <td>  2759  </td>,
#  <td>  0  </td>,
#  <td>  37  </td>,
#  <td>  10  </td>,
#  <td>12</td>,
#  <td class="subeElo">↑1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Anand, Viswanathan&amp;id=5000017">    Anand, Viswanathan     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/in.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="India" width="35"/></td>,
#  <td>  2756  </td>,
#  <td>  0  </td>,
#  <td>  53  </td>,
#  <td>  10  </td>,
#  <td>13</td>,
#  <td class="subeElo">↑1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Dominguez Perez, Leinier&amp;id=3503240">    Dominguez Perez, Leinier     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2754  </td>,
#  <td>  0  </td>,
#  <td>  39  </td>,
#  <td>  10  </td>,
#  <td>14</td>,
#  <td class="bajaElo">↓6</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Rapport, Richard&amp;id=738590">    Rapport, Richard     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/hu.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Hungary" width="35"/></td>,
#  <td>  2750.6  </td>,
#  <td class="bajaElo">  -13.4  </td>,
#  <td>  26  </td>,
#  <td>  10  </td>,
#  <td>15</td>,
#  <td class="subeElo">↑3</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Radjabov, Teimour&amp;id=13400924">    Radjabov, Teimour     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/az.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Azerbaijan" width="35"/></td>,
#  <td>  2747.4  </td>,
#  <td class="subeElo"> +9.4  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>16</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Karjakin, Sergey&amp;id=14109603">    Karjakin, Sergey     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2747  </td>,
#  <td>  0  </td>,
#  <td>  32  </td>,
#  <td>  10  </td>,
#  <td>17</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Grischuk, Alexander&amp;id=4126025">    Grischuk, Alexander     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2745  </td>,
#  <td>  0  </td>,
#  <td>  39  </td>,
#  <td>  10  </td>,
#  <td>18</td>,
#  <td class="bajaElo">↓3</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Duda, Jan-Krzysztof&amp;id=1170546">    Duda, Jan-Krzysztof     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/pl.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Poland" width="35"/></td>,
#  <td>  2739.8  </td>,
#  <td class="bajaElo">  -10.2  </td>,
#  <td>  24  </td>,
#  <td>  10  </td>,
#  <td>19</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Wang, Hao&amp;id=8602883">    Wang, Hao     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2735  </td>,
#  <td>  0  </td>,
#  <td>  33  </td>,
#  <td>  10  </td>,
#  <td>20</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Andreikin, Dmitry&amp;id=4158814">    Andreikin, Dmitry     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2729  </td>,
#  <td>  0  </td>,
#  <td>  32  </td>,
#  <td>  10  </td>,
#  <td>21</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Topalov, Veselin&amp;id=2900084">    Topalov, Veselin     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/bg.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Bulgaria" width="35"/></td>,
#  <td>  2728  </td>,
#  <td>  0  </td>,
#  <td>  47  </td>,
#  <td>  10  </td>,
#  <td>22</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Wei, Yi&amp;id=8603405">    Wei, Yi     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2727  </td>,
#  <td>  0  </td>,
#  <td>  23  </td>,
#  <td>  10  </td>,
#  <td>23</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Le, Quang Liem&amp;id=12401137">    Le, Quang Liem     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/vn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Vietnam" width="35"/></td>,
#  <td>  2722  </td>,
#  <td>  0  </td>,
#  <td>  31  </td>,
#  <td>  10  </td>,
#  <td>24</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Vitiugov, Nikita&amp;id=4152956">    Vitiugov, Nikita     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2722  </td>,
#  <td>  0  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>25</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Yu, Yangyi&amp;id=8603820">    Yu, Yangyi     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2720  </td>,
#  <td>  0  </td>,
#  <td>  28  </td>,
#  <td>  10  </td>,
#  <td>26</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Shankland, Sam&amp;id=2004887">    Shankland, Sam     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2720  </td>,
#  <td>  0  </td>,
#  <td>  31  </td>,
#  <td>  10  </td>,
#  <td>27</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Harikrishna, Pentala&amp;id=5007003">    Harikrishna, Pentala     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/in.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="India" width="35"/></td>,
#  <td>  2720  </td>,
#  <td>  0  </td>,
#  <td>  36  </td>,
#  <td>  10  </td>,
#  <td>28</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Vidit, Santosh Gujrathi&amp;id=5029465">    Vidit, Santosh Gujrathi     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/in.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="India" width="35"/></td>,
#  <td>  2714  </td>,
#  <td>  0  </td>,
#  <td>  28  </td>,
#  <td>  10  </td>,
#  <td>29</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Bu, Xiangzhi&amp;id=8601445">    Bu, Xiangzhi     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2709  </td>,
#  <td>  0  </td>,
#  <td>  37  </td>,
#  <td>  10  </td>,
#  <td>30</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Alekseenko, Kirill&amp;id=4135539">    Alekseenko, Kirill     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2708  </td>,
#  <td>  0  </td>,
#  <td>  25  </td>,
#  <td>  10  </td>,
#  <td>31</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Wojtaszek, Radoslaw&amp;id=1118358">    Wojtaszek, Radoslaw     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/pl.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Poland" width="35"/></td>,
#  <td>  2708  </td>,
#  <td>  0  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>32</td>,
#  <td class="subeElo">↑7</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Sjugirov, Sanan&amp;id=4189302">    Sjugirov, Sanan     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2704.5  </td>,
#  <td class="subeElo"> +8.5  </td>,
#  <td>  29  </td>,
#  <td>  10  </td>,
#  <td>33</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Shirov, Alexei&amp;id=2209390">    Shirov, Alexei     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/es.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Spain" width="35"/></td>,
#  <td>  2704  </td>,
#  <td>  0  </td>,
#  <td>  50  </td>,
#  <td>  10  </td>,
#  <td>34</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Dubov, Daniil&amp;id=24126055">    Dubov, Daniil     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2702  </td>,
#  <td>  0  </td>,
#  <td>  26  </td>,
#  <td>  10  </td>,
#  <td>35</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Tomashevsky, Evgeny&amp;id=4147235">    Tomashevsky, Evgeny     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2702  </td>,
#  <td>  0  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>36</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Vallejo Pons, Francisco&amp;id=2205530">    Vallejo Pons, Francisco     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/es.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Spain" width="35"/></td>,
#  <td>  2702  </td>,
#  <td>  0  </td>,
#  <td>  40  </td>,
#  <td>  10  </td>,
#  <td>37</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Maghsoodloo, Parham&amp;id=12539929">    Maghsoodloo, Parham     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ir.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Iran" width="35"/></td>,
#  <td>  2701  </td>,
#  <td>  0  </td>,
#  <td>  22  </td>,
#  <td>  10  </td>,
#  <td>38</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Artemiev, Vladislav&amp;id=24101605">    Artemiev, Vladislav     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2699.6  </td>,
#  <td class="subeElo"> +2.6  </td>,
#  <td>  24  </td>,
#  <td>  10  </td>,
#  <td>39</td>,
#  <td class="bajaElo">↓2</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Sargissian, Gabriel&amp;id=13300881">    Sargissian, Gabriel     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/am.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Armenia" width="35"/></td>,
#  <td>  2698  </td>,
#  <td>  0  </td>,
#  <td>  39  </td>,
#  <td>  10  </td>,
#  <td>40</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Adams, Michael&amp;id=400041">    Adams, Michael     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/gb.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="UNITED KINGDOM" width="35"/></td>,
#  <td>  2696  </td>,
#  <td>  0  </td>,
#  <td>  51  </td>,
#  <td>  10  </td>,
#  <td>41</td>,
#  <td class="subeElo">↑12</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Gukesh D&amp;id=46616543">    Gukesh D     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/in.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="India" width="35"/></td>,
#  <td>  2693.7  </td>,
#  <td class="subeElo"> +9.7  </td>,
#  <td>  16  </td>,
#  <td>  10  </td>,
#  <td>42</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Deac, Bogdan-Daniel&amp;id=1226380">    Deac, Bogdan-Daniel     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ro.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Romania" width="35"/></td>,
#  <td>  2692  </td>,
#  <td>  0  </td>,
#  <td>  21  </td>,
#  <td>  10  </td>,
#  <td>43</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Korobov, Anton&amp;id=14105730">    Korobov, Anton     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2692  </td>,
#  <td>  0  </td>,
#  <td>  37  </td>,
#  <td>  10  </td>,
#  <td>44</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Xiong, Jeffery&amp;id=2047640">    Xiong, Jeffery     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2691  </td>,
#  <td>  0  </td>,
#  <td>  22  </td>,
#  <td>  10  </td>,
#  <td>45</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Erigaisi Arjun&amp;id=35009192">    Erigaisi Arjun     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/in.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="India" width="35"/></td>,
#  <td>  2689  </td>,
#  <td>  0  </td>,
#  <td>  19  </td>,
#  <td>  10  </td>,
#  <td>46</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Abdusattorov, Nodirbek&amp;id=14204118">    Abdusattorov, Nodirbek     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/uz.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Uzbekistan" width="35"/></td>,
#  <td>  2688  </td>,
#  <td>  0  </td>,
#  <td>  18  </td>,
#  <td>  10  </td>,
#  <td>47</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Niemann, Hans Moke&amp;id=2093596">    Niemann, Hans Moke     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2688  </td>,
#  <td>  0  </td>,
#  <td>  19  </td>,
#  <td>  10  </td>,
#  <td>48</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Predke, Alexandr&amp;id=24107581">    Predke, Alexandr     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2688  </td>,
#  <td>  0  </td>,
#  <td>  28  </td>,
#  <td>  10  </td>,
#  <td>49</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Navara, David&amp;id=309095">    Navara, David     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cz.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Czech Republic" width="35"/></td>,
#  <td>  2688  </td>,
#  <td>  0  </td>,
#  <td>  37  </td>,
#  <td>  10  </td>,
#  <td>50</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Keymer, Vincent&amp;id=12940690">    Keymer, Vincent     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/de.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Germany" width="35"/></td>,
#  <td>  2686  </td>,
#  <td>  0  </td>,
#  <td>  18  </td>,
#  <td>  10  </td>,
#  <td>51</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Nyzhnyk, Illya&amp;id=14118084">    Nyzhnyk, Illya     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2686  </td>,
#  <td>  0  </td>,
#  <td>  26  </td>,
#  <td>  10  </td>,
#  <td>52</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Fedoseev, Vladimir&amp;id=24130737">    Fedoseev, Vladimir     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2686  </td>,
#  <td>  0  </td>,
#  <td>  27  </td>,
#  <td>  10  </td>,
#  <td>53</td>,
#  <td class="bajaElo">↓1</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Cheparinov, Ivan&amp;id=2905540">    Cheparinov, Ivan     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/bg.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Bulgaria" width="35"/></td>,
#  <td>  2685  </td>,
#  <td>  0  </td>,
#  <td>  36  </td>,
#  <td>  10  </td>,
#  <td>54</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Sevian, Samuel&amp;id=2040506">    Sevian, Samuel     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2684  </td>,
#  <td>  0  </td>,
#  <td>  22  </td>,
#  <td>  10  </td>,
#  <td>55</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Salem, A.R. Saleh&amp;id=9301348">    Salem, A.R. Saleh     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ae.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United Arab Emirates" width="35"/></td>,
#  <td>  2684  </td>,
#  <td>  0  </td>,
#  <td>  29  </td>,
#  <td>  10  </td>,
#  <td>56</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Oparin, Grigoriy&amp;id=24125890">    Oparin, Grigoriy     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2683  </td>,
#  <td>  0  </td>,
#  <td>  25  </td>,
#  <td>  10  </td>,
#  <td>57</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Svidler, Peter&amp;id=4102142">    Svidler, Peter     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2683  </td>,
#  <td>  0  </td>,
#  <td>  46  </td>,
#  <td>  10  </td>,
#  <td>58</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Esipenko, Andrey&amp;id=24175439">    Esipenko, Andrey     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2682  </td>,
#  <td>  0  </td>,
#  <td>  20  </td>,
#  <td>  10  </td>,
#  <td>59</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Robson, Ray&amp;id=2023970">    Robson, Ray     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2682  </td>,
#  <td>  0  </td>,
#  <td>  28  </td>,
#  <td>  10  </td>,
#  <td>60</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Jakovenko, Dmitry&amp;id=4122356">    Jakovenko, Dmitry     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2682  </td>,
#  <td>  0  </td>,
#  <td>  39  </td>,
#  <td>  10  </td>,
#  <td>61</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Eljanov, Pavel&amp;id=14102951">    Eljanov, Pavel     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2681  </td>,
#  <td>  0  </td>,
#  <td>  39  </td>,
#  <td>  10  </td>,
#  <td>62</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Saric, Ivan&amp;id=14508150">    Saric, Ivan     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/hr.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Croatia" width="35"/></td>,
#  <td>  2680  </td>,
#  <td>  0  </td>,
#  <td>  32  </td>,
#  <td>  10  </td>,
#  <td>63</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Amin, Bassem&amp;id=10601457">    Amin, Bassem     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/eg.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Egypt" width="35"/></td>,
#  <td>  2680  </td>,
#  <td>  0  </td>,
#  <td>  34  </td>,
#  <td>  10  </td>,
#  <td>64</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Li, Chao b&amp;id=8604436">    Li, Chao b     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2679  </td>,
#  <td>  0  </td>,
#  <td>  33  </td>,
#  <td>  10  </td>,
#  <td>65</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Van Foreest, Jorden&amp;id=1039784">    Van Foreest, Jorden     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/nl.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Netherlands" width="35"/></td>,
#  <td>  2678  </td>,
#  <td>  0  </td>,
#  <td>  23  </td>,
#  <td>  10  </td>,
#  <td>66</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Almasi, Zoltan&amp;id=702293">    Almasi, Zoltan     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/hu.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Hungary" width="35"/></td>,
#  <td>  2677  </td>,
#  <td>  0  </td>,
#  <td>  46  </td>,
#  <td>  10  </td>,
#  <td>67</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Najer, Evgeniy&amp;id=4118987">    Najer, Evgeniy     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2676  </td>,
#  <td>  0  </td>,
#  <td>  45  </td>,
#  <td>  10  </td>,
#  <td>68</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Santos Latasa, Jaime&amp;id=2293307">    Santos Latasa, Jaime     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/es.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Spain" width="35"/></td>,
#  <td>  2675  </td>,
#  <td>  0  </td>,
#  <td>  26  </td>,
#  <td>  10  </td>,
#  <td>69</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Polgar, Judit&amp;id=700070">    Polgar, Judit     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/hu.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Hungary" width="35"/></td>,
#  <td>  2675  </td>,
#  <td>  0  </td>,
#  <td>  46  </td>,
#  <td>  10  </td>,
#  <td>70</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Kovalenko, Igor&amp;id=14117908">    Kovalenko, Igor     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2674  </td>,
#  <td>  0  </td>,
#  <td>  34  </td>,
#  <td>  10  </td>,
#  <td>71</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Volokitin, Andrei&amp;id=14107090">    Volokitin, Andrei     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2674  </td>,
#  <td>  0  </td>,
#  <td>  36  </td>,
#  <td>  10  </td>,
#  <td>72</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Bluebaum, Matthias&amp;id=24651516">    Bluebaum, Matthias     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/de.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Germany" width="35"/></td>,
#  <td>  2673  </td>,
#  <td>  0  </td>,
#  <td>  25  </td>,
#  <td>  10  </td>,
#  <td>73</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Martirosyan, Haik M.&amp;id=13306553">    Martirosyan, Haik M.     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/am.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Armenia" width="35"/></td>,
#  <td>  2672  </td>,
#  <td>  0  </td>,
#  <td>  22  </td>,
#  <td>  10  </td>,
#  <td>74</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Tari, Aryan&amp;id=1510045">    Tari, Aryan     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/no.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Norway" width="35"/></td>,
#  <td>  2672  </td>,
#  <td>  0  </td>,
#  <td>  23  </td>,
#  <td>  10  </td>,
#  <td>75</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Moussard, Jules&amp;id=642908">    Moussard, Jules     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fr.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="France" width="35"/></td>,
#  <td>  2672  </td>,
#  <td>  0  </td>,
#  <td>  27  </td>,
#  <td>  10  </td>,
#  <td>76</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Kryvoruchko, Yuriy&amp;id=14109182">    Kryvoruchko, Yuriy     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2672  </td>,
#  <td>  0  </td>,
#  <td>  36  </td>,
#  <td>  10  </td>,
#  <td>77</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Kasimdzhanov, Rustam&amp;id=14200244">    Kasimdzhanov, Rustam     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/uz.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Uzbekistan" width="35"/></td>,
#  <td>  2672  </td>,
#  <td>  0  </td>,
#  <td>  43  </td>,
#  <td>  10  </td>,
#  <td>78</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Matlakov, Maxim&amp;id=4168003">    Matlakov, Maxim     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2671  </td>,
#  <td>  0  </td>,
#  <td>  31  </td>,
#  <td>  10  </td>,
#  <td>79</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Areshchenko, Alexander&amp;id=14109530">    Areshchenko, Alexander     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2671  </td>,
#  <td>  0  </td>,
#  <td>  36  </td>,
#  <td>  10  </td>,
#  <td>80</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Sarana, Alexey&amp;id=24133795">    Sarana, Alexey     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2668  </td>,
#  <td>  0  </td>,
#  <td>  22  </td>,
#  <td>  10  </td>,
#  <td>81</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Guseinov, Gadir&amp;id=13401378">    Guseinov, Gadir     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/az.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Azerbaijan" width="35"/></td>,
#  <td>  2668  </td>,
#  <td>  0  </td>,
#  <td>  36  </td>,
#  <td>  10  </td>,
#  <td>82</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Ni, Hua&amp;id=8601160">    Ni, Hua     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2668  </td>,
#  <td>  0  </td>,
#  <td>  39  </td>,
#  <td>  10  </td>,
#  <td>83</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Gelfand, Boris&amp;id=2805677">    Gelfand, Boris     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/il.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Israel" width="35"/></td>,
#  <td>  2668  </td>,
#  <td>  0  </td>,
#  <td>  54  </td>,
#  <td>  10  </td>,
#  <td>84</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Anton Guijarro, David&amp;id=2285525">    Anton Guijarro, David     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/es.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Spain" width="35"/></td>,
#  <td>  2667  </td>,
#  <td>  0  </td>,
#  <td>  27  </td>,
#  <td>  10  </td>,
#  <td>85</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Ma, Qun&amp;id=8603154">    Ma, Qun     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/cn.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="China" width="35"/></td>,
#  <td>  2666  </td>,
#  <td>  0  </td>,
#  <td>  31  </td>,
#  <td>  10  </td>,
#  <td>86</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Tabatabaei, M. Amin&amp;id=12521213">    Tabatabaei, M. Amin     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ir.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Iran" width="35"/></td>,
#  <td>  2664  </td>,
#  <td>  0  </td>,
#  <td>  21  </td>,
#  <td>  10  </td>,
#  <td>87</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Naiditsch, Arkadij&amp;id=4650891">    Naiditsch, Arkadij     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/az.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Azerbaijan" width="35"/></td>,
#  <td>  2664  </td>,
#  <td>  0  </td>,
#  <td>  37  </td>,
#  <td>  10  </td>,
#  <td>88</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Sargsyan, Shant&amp;id=13306766">    Sargsyan, Shant     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/am.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Armenia" width="35"/></td>,
#  <td>  2661  </td>,
#  <td>  0  </td>,
#  <td>  20  </td>,
#  <td>  10  </td>,
#  <td>89</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Inarkiev, Ernesto&amp;id=4162722">    Inarkiev, Ernesto     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ru.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Russia" width="35"/></td>,
#  <td>  2661  </td>,
#  <td>  0  </td>,
#  <td>  37  </td>,
#  <td>  10  </td>,
#  <td>90</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Narayanan.S.L&amp;id=5058422">    Narayanan.S.L     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/in.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="India" width="35"/></td>,
#  <td>  2659  </td>,
#  <td>  0  </td>,
#  <td>  24  </td>,
#  <td>  10  </td>,
#  <td>91</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Mareco, Sandro&amp;id=112275">    Mareco, Sandro     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ar.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Argentina" width="35"/></td>,
#  <td>  2657  </td>,
#  <td>  0  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>92</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Mamedov, Rauf&amp;id=13401653">    Mamedov, Rauf     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/az.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Azerbaijan" width="35"/></td>,
#  <td>  2656  </td>,
#  <td>  0  </td>,
#  <td>  34  </td>,
#  <td>  10  </td>,
#  <td>93</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Bacrot, Etienne&amp;id=605506">    Bacrot, Etienne     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fr.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="France" width="35"/></td>,
#  <td>  2656  </td>,
#  <td>  0  </td>,
#  <td>  39  </td>,
#  <td>  10  </td>,
#  <td>94</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Grandelius, Nils&amp;id=1710400">    Grandelius, Nils     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/se.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Sweden" width="35"/></td>,
#  <td>  2655  </td>,
#  <td>  0  </td>,
#  <td>  29  </td>,
#  <td>  10  </td>,
#  <td>95</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Kamsky, Gata&amp;id=2000024">    Kamsky, Gata     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2655  </td>,
#  <td>  0  </td>,
#  <td>  48  </td>,
#  <td>  10  </td>,
#  <td>96</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Shevchenko, Kirill&amp;id=14129574">    Shevchenko, Kirill     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/ua.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="Ukraine" width="35"/></td>,
#  <td>  2654  </td>,
#  <td>  0  </td>,
#  <td>  20  </td>,
#  <td>  10  </td>,
#  <td>97</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Demchenko, Anton&amp;id=4160258">    Demchenko, Anton     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/fd.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="FIDE" width="35"/></td>,
#  <td>  2653  </td>,
#  <td>  0  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>98</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Swiercz, Dariusz&amp;id=1126881">    Swiercz, Dariusz     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/us.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="United States" width="35"/></td>,
#  <td>  2652  </td>,
#  <td>  0  </td>,
#  <td>  28  </td>,
#  <td>  10  </td>,
#  <td>99</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Jones, Gawain C B&amp;id=409561">    Jones, Gawain C B     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/gb.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="UNITED KINGDOM" width="35"/></td>,
#  <td>  2652  </td>,
#  <td>  0  </td>,
#  <td>  35  </td>,
#  <td>  10  </td>,
#  <td>100</td>,
#  <td>-</td>,
#  <td class="nombre"><a href="https://chess-rankings.com/jugador.php?nombre=Nihal Sarin&amp;id=25092340">    Nihal Sarin     </a></td>,
#  <td class="GM" style="font-weight:bold;">  GM  </td>,
#  <td><img height="22" src="https://chess-rankings.com/img/banderas/in.png" style="border: 1px solid #CCCCE0;box-shadow: 1px 1px 1px grey;" title="India" width="35"/></td>,
#  <td>  2651  </td>,
#  <td>  0  </td>,
#  <td>  18  </td>,
#  <td>  10  </td>]

# %%
rows[0].find_all('td')[2].text.strip()
# Out:
# 'Carlsen, Magnus'

# %%
rows[0].find_all('td')[4].img['title'].strip()
# Out:
# 'Norway'

# %% [markdown]
# #### Appending values from rows in dictionary's value
#
# Each row (tr_tag) contains 9 'td_tag' tags which contains details about each palyer.
#
# ![](https://i.imgur.com/DVrVAhX.png)

# %%
for row in rows:
    rank.append(row.find_all('td')[0].text.strip())
    rank_change.append(row.find_all('td')[1].text.strip())
    name.append(row.find_all('td')[2].text.strip())
    title.append(row.find_all('td')[3].text.strip())
    fed.append(row.find_all('td')[4].img['title'].strip())
    rating.append(row.find_all('td')[5].text.strip())
    rating_change.append(row.find_all('td')[6].text.strip())
    age.append(row.find_all('td')[7].text.strip())
    k.append(row.find_all('td')[8].text.strip())

# %% [markdown]
# #### Converting dictionary into a DataFrame

# %%
import pandas as pd
df = pd.DataFrame(table_dict)
df
# Out:
#    Rank Rank Change                 Name Title      Federation FIDE Rating  \
# 0     1           -      Carlsen, Magnus    GM          Norway        2864
# 1     2           -          Ding, Liren    GM           China      2808.4
# 2     3          ↑4  Nepomniachtchi, Ian    GM          Russia      2792.4
# 3     4          ↓1    Firouzja, Alireza    GM          France      2778.2
# 4     5          ↓1     Caruana, Fabiano    GM   United States      2775.4
# ..  ...         ...                  ...   ...             ...         ...
# 95   96           -   Shevchenko, Kirill    GM         Ukraine        2654
# 96   97           -     Demchenko, Anton    GM            FIDE        2653
# 97   98           -     Swiercz, Dariusz    GM   United States        2652
# 98   99           -    Jones, Gawain C B    GM  UNITED KINGDOM        2652
# 99  100           -          Nihal Sarin    GM           India        2651
#
#    Rating Change Age   K
# 0              0  32  10
# 1           +2.4  30  10
# 2          +26.4  32  10
# 3          -14.8  19  10
# 4           -7.6  30  10
# ..           ...  ..  ..
# 95             0  20  10
# 96             0  35  10
# 97             0  28  10
# 98             0  35  10
# 99             0  18  10
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Creating helper functions for separate tasks

# %% [markdown]
# ##### Helper function for fetching page and parse with BeautifulSoup()

# %%
# Creating function fetching page and parse with BeautifulSoup()
def get_page(url):
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception('Failed to load page {}'.format(url))
    page_content = response.text
    return BeautifulSoup(page_content,'html.parser')

# %% [markdown]
# ##### Helper function which will return dictionary

# %%
# Creating function which will return dictionary
def get_dict():
    rank = []
    rank_change = []
    name = []
    title = []
    fed = []
    rating = []
    rating_change = []
    age = []
    k = []
    table_dict = {'Rank': rank,'Rank Change': rank_change,'Name': name,'Title':title,'Federation':fed,'FIDE Rating': rating,
                 'Rating Change':rating_change,'Age':age,'K':k}
    return table_dict

# %% [markdown]
# ##### Helper function for getting data from the rows and appending it into dictionary

# %%
# Creating function for getting data from the rows and appending it into dictionary
def get_rows(doc,table_dict):              
    rows = doc.tbody.find_all('tr')
    table_dict = table_dict
    for row in rows:
        table_dict['Rank'].append(row.find_all('td')[0].text.strip())
        table_dict['Rank Change'].append(row.find_all('td')[1].text.strip())
        table_dict['Name'].append(row.find_all('td')[2].text.strip())
        table_dict['Title'].append(row.find_all('td')[3].text.strip())
        table_dict['Federation'].append(row.find_all('td')[4].img['title'].strip())
        table_dict['FIDE Rating'].append(row.find_all('td')[5].text.strip())
        table_dict['Rating Change'].append(row.find_all('td')[6].text.strip())
        table_dict['Age'].append(row.find_all('td')[7].text.strip())
        table_dict['K'].append(row.find_all('td')[8].text.strip())
    return table_dict

# %% [markdown]
# ##### Helper function for getting data from the rows and appending it into dictionary

# %%
# Creating function for getting data from the rows and appending it into dictionary
def get_rows(doc,table_dict):              
    rows = doc.tbody.find_all('tr')
    table_dict = table_dict
    for row in rows:
        table_dict['Rank'].append(row.find_all('td')[0].text.strip())
        table_dict['Rank Change'].append(row.find_all('td')[1].text.strip())
        table_dict['Name'].append(row.find_all('td')[2].text.strip())
        table_dict['Title'].append(row.find_all('td')[3].text.strip())
        table_dict['Federation'].append(row.find_all('td')[4].img['title'].strip())
        table_dict['FIDE Rating'].append(row.find_all('td')[5].text.strip())
        table_dict['Rating Change'].append(row.find_all('td')[6].text.strip())
        table_dict['Age'].append(row.find_all('td')[7].text.strip())
        table_dict['K'].append(row.find_all('td')[8].text.strip())
    return table_dict

# %% [markdown]
# ##### Helper function for converting Dictionary into DataFrame

# %%
# Creating function for converting Dictionary into DataFrame
def get_df(dictionary):
    df = pd.DataFrame(dictionary)
    return df

# %% [markdown]
# ##### Helper function for writing CSV file

# %%
# Creating function for writing CSV file 
def write_csv(dataframe,fideRating):
    file_name = 'top_100_player_under_'+str(fideRating)+'.csv'
    dataframe.to_csv(file_name,index=False)

# %% [markdown]
# #### Master function which takes url and store data in CSV file

# %%
# Creating function which takes url as argument and return    
def get_players(url):
    fideRating = url[34:38]
    doc = get_page(url)
    table_dict = get_dict()
    table_dict = get_rows(doc,table_dict)
    df = get_df(table_dict)
    write_csv(df,fideRating)
    file_name = 'top_100_player_under_'+str(fideRating)+'.csv'
    return 'Top 100 Players Under "{}" written to file "{}"'.format(fideRating,file_name )

# %%
get_players('https://chess-rankings.com/?categ=3000&label=1')
# Out:
# 'Top 100 Players Under "3000" written to file "top_100_player_under_3000.csv"'

# %%
data = pd.read_csv("top_100_player_under_3000.csv")
data
# Out:
#     Rank Rank Change                 Name Title      Federation  FIDE Rating  \
# 0      1           -      Carlsen, Magnus    GM          Norway       2864.0
# 1      2           -          Ding, Liren    GM           China       2808.4
# 2      3          ↑4  Nepomniachtchi, Ian    GM          Russia       2792.4
# 3      4          ↓1    Firouzja, Alireza    GM          France       2778.2
# 4      5          ↓1     Caruana, Fabiano    GM   United States       2775.4
# ..   ...         ...                  ...   ...             ...          ...
# 95    96           -   Shevchenko, Kirill    GM         Ukraine       2654.0
# 96    97           -     Demchenko, Anton    GM            FIDE       2653.0
# 97    98           -     Swiercz, Dariusz    GM   United States       2652.0
# 98    99           -    Jones, Gawain C B    GM  UNITED KINGDOM       2652.0
# 99   100           -          Nihal Sarin    GM           India       2651.0
#
#     Rating Change  Age   K
# 0             0.0   32  10
# 1             2.4   30  10
# 2            26.4   32  10
# 3           -14.8   19  10
# 4            -7.6   30  10
# ..            ...  ...  ..
# 95            0.0   20  10
# 96            0.0   35  10
# 97            0.0   28  10
# 98            0.0   35  10
# 99            0.0   18  10
#
# [100 rows x 9 columns]

# %%
get_players('https://chess-rankings.com/?categ=2300&label=2')
# Out:
# 'Top 100 Players Under "2300" written to file "top_100_player_under_2300.csv"'

# %%
data_1 = pd.read_csv("top_100_player_under_2300.csv")
data_1
# Out:
#     Rank Rank Change                         Name Title      Federation  \
# 0      1           -        Van Foreest, Machteld    FM     Netherlands
# 1      2           -             Bulockin, Martin    FM  Czech Republic
# 2      3           -               Wendler, David   NaN         Germany
# 3      4          ↑1          Yakubbaeva, Nilufar   WGM      Uzbekistan
# 4      5          ↑1     Garcia Garcia, Alejandro    FM            Cuba
# ..   ...         ...                          ...   ...             ...
# 95    96          ↑1  Perpinya Rofes, Lluis Maria    IM           Spain
# 96    97          ↑1               Merriman, John    FM  UNITED KINGDOM
# 97    98          ↑1              Rechmann, Peter    FM         Germany
# 98    99          ↑1               Martin, Thomas    FM         Germany
# 99   100          ↑1                 Molnar, Bela    IM         Hungary
#
#     FIDE Rating  Rating Change  Age   K
# 0        2299.0            0.0   15  40
# 1        2299.0            0.0   20  20
# 2        2299.0            0.0   21  20
# 3        2299.0            0.0   22  20
# 4        2299.0            0.0   23  20
# ..          ...            ...  ...  ..
# 95       2297.0            0.0   48  10
# 96       2297.0            0.0   48  20
# 97       2297.0            0.0   55  20
# 98       2297.0            0.0   56  20
# 99       2297.0            0.0   57  10
#
# [100 rows x 9 columns]

# %% [markdown]
# # **Summary**
#
# - The Scraping was done using Python libraries such as Requests, BeatifulSoup for extracting the data
# - Scraping Top 100 chess players details such as Rank, Name, Federation, Rating, Age etc.
# - Parsed all the scraped data into a csv file containing 100 rows and 9 columns.

# %% [markdown]
# # **References**
#
# https://chess-rankings.com/
#
# https://www.youtube.com/watch?v=RKsLLG-bzEY
#
# https://dorianlazar.medium.com/scraping-medium-with-python-beautiful-soup-3314f898bbf5
